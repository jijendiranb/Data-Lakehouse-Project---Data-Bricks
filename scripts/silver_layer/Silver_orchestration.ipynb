# %% [markdown]
# #Orchestration Logic

# %%
notebooks = [
    "./Silver_Layer_Customer_info",
    "./Silver_Layer_Product_info",
    "./Silver_Layer_Sales_details",
    "./Silver_Layer_erp_cust_az12",
    "./Silver_Layer_erp_loc_a101",
    "./Silver_Layer_erp_px_cat_g1v2"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
