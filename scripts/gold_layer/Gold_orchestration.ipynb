# %% [markdown]
# #Orchestration Logic

# %%
notebooks = [
    "./Gold_Layer_dim_customer",
    "./Gold_Layer_dim_product",
    "./Gold_Layer_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
